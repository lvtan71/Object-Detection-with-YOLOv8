# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.4/589.4 kB 37.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 23.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/107.7 GB disk)

# %%
# !yolo predict model='your/trained/model/path' source='https://images.pexels.com/photos/3184419/pexels-photo-3184419.jpeg'
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# ...
# 100% 13.8M/13.8M [00:00<00:00, 126MB/s]
# image 1/1 /content/pexels-photo-3184419.jpeg: 448x640 6 Humans, 402.1ms
# Speed: 13.3ms preprocess, 402.1ms inference, 24.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# !yolo predict model='your/trained/model/path' source='https://images.ctfassets.net/hrltx12pl8hq/797m9B0ewbFDn9U61e1gNz/cb67336c4291801c104bc0a240fce6e1/Diverse-people.jpg'
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# ...
# 100% 142k/142k [00:00<00:00, 42.0MB/s]
# image 1/1 /content/Diverse-people.jpg: 448x640 6 Humans, 325.7ms
# Speed: 3.9ms preprocess, 325.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3

# %%
# !yolo predict model='your/trained/model/path' source='/content/istockphoto-1270596407-1024x1024.jpg'
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
#
# image 1/1 /content/istockphoto-1270596407-1024x1024.jpg: 448x640 3 Humans, 297.2ms
# Speed: 2.3ms preprocess, 297.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
